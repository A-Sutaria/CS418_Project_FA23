# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# ZHVI
file_1 = 'ZHVI.csv'

first_row = df.iloc[0]
x = first_row.index[5:].to_numpy()
y = first_row.iloc[5:].to_numpy()

years = [datetime.strptime(date, '%Y-%m-%d').year for date in x]

plt.figure(figsize=(12, 8)) 

# Plot the graph
plt.plot(years, y, marker='o', linestyle='-', color='black', linewidth=0.000001)

# Labels and title
plt.xlabel('2000 - 2023')
plt.ylabel('Price')
plt.title('Graph of Price vs Time in U.S of ZHVI')



# Show
plt.tight_layout()
plt.show()
