# %%
import pandas as pd
import matplotlib.pyplot as plt

# ZHVI
file_1 = 'ZHVI.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_1)

first_row = df.iloc[0]
x = first_row.index[5:].to_numpy()
y = first_row.iloc[5:].to_numpy()

plt.figure(figsize=(12, 8)) 

# Plot the graph
plt.plot(x, y, marker='o', linestyle='-', color='black', linewidth=0.000001)

# x-axis as dates
plt.gca().x.set_major_formatter(mdates.DateFormatter('%m/%d/%y'))

# Labels and title
plt.xlabel('2000 - 2023')
plt.ylabel('Price')
plt.title('Graph of Price vs Time in U.S of ZHVI')



# Show
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/htinlinnhtoothan/Downloads/untitled folder/ZHVI.ipynb Cell 1 line <cell line: 20>()
#      <a href='vscode-notebook-cell:/Users/htinlinnhtoothan/Downloads/untitled%20folder/ZHVI.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> plt.plot(x, y, marker='o', linestyle='-', color='black', linewidth=0.000001)
#      <a href='vscode-notebook-cell:/Users/htinlinnhtoothan/Downloads/untitled%20folder/ZHVI.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a> # x-axis as dates
# ---> <a href='vscode-notebook-cell:/Users/htinlinnhtoothan/Downloads/untitled%20folder/ZHVI.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> plt.gca().x.set_major_formatter(mdates.DateFormatter('%m/%d/%y'))
#      <a href='vscode-notebook-cell:/Users/htinlinnhtoothan/Downloads/untitled%20folder/ZHVI.ipynb#W3sZmlsZQ%3D%3D?line=21'>22</a> # Labels and title
# ...
